# %%
import pandas as pd
from pymongo import MongoClient
from pathlib import Path

# %%
#chemin d'acces dossier
csv_path = Path(r"C:\Users\paule\Documents\OpenCR\Projet 5 - MongoDB\opc-mongodb\healthcare_dataset.csv")

# %%
csv_path = "C:/Users/paule/Documents/OpenCR/Projet 5 - MongoDB/opc-mongodb/healthcare_dataset.csv"

# %%
df_healthcare = pd.read_csv(csv_path)

# %%
df_healthcare.head(5)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df_healthcare[df_healthcare['Hospital'] == 'Moreno Murphy, Griffith and']
# Out:
#                Name  Age Gender Blood Type Medical Condition  \
# 49997  Lisa Simpson   73   Male         O-            Cancer
#
#       Date of Admission          Doctor                     Hospital  \
# 49997        2023-09-08  Deborah Sutton  Moreno Murphy, Griffith and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 49997         Blue Cross     8441.147064          411       Elective
#
#       Discharge Date Medication Test Results
# 49997     2023-09-22    Aspirin     Abnormal

# %%
df_healthcare['Name'] = df_healthcare['Name'].str.title()

# %%
records = df_healthcare.to_dict(orient="records")

# %%
records
# Out:
# [{'Name': 'Bobby Jackson',
#   'Age': 30,
#   'Gender': 'Male',
#   'Blood Type': 'B-',
#   'Medical Condition': 'Cancer',
#   'Date of Admission': '2024-01-31',
#   'Doctor': 'Matthew Smith',
#   'Hospital': 'Sons and Miller',
#   'Insurance Provider': 'Blue Cross',
#   'Billing Amount': 18856.281305978155,
#   'Room Number': 328,
#   'Admission Type': 'Urgent',
#   'Discharge Date': '2024-02-02',
#   'Medication': 'Paracetamol',
#   'Test Results': 'Normal'},
#  {'Name': 'Leslie Terry',
#   'Age': 62,
#   'Gender': 'Male',
#   'Blood Type': 'A+',
#   'Medical Condition': 'Obesity',
#   'Date of Admission': '2019-08-20',
#   'Doctor': 'Samantha Davies',
#   'Hospital': 'Kim Inc',
#   'Insurance Provider': 'Medicare',
#   'Billing Amount': 33643.327286577885,
#   'Room Number': 265,
#   'Admission Type': 'Emergency',
#   'Discharge Date': '2019-08-26',
#   'Medication': 'Ibuprofen',
#   'Test Results': 'Inconclusive'},
#  {'Name': 'Danny Smith',
#   'Age': 76,
# ...

# %%
MONGO_URI      = "mongodb://localhost:27017"
DB_NAME        = "mydb"
COLLECTION_NAME= "mycollection"

# %%
client = MongoClient(MONGO_URI)
coll = client[DB_NAME][COLLECTION_NAME]

# %%
result = coll.insert_many(records)
